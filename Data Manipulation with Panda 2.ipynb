# %%
import pandas as pdp;/
port numpy as np

# %%
import numpy as np

# %%
# load data
df=pd.read_csv('Data_csv')

# %%
df.head(2)
# Out:
#    EMP_ID     FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 0       0  André Fonseca  Production    3500                 350
# 1       1      Ann devon    Engineer    4003                 250
#
#         MANAGERS  ID  INVENTORY ID  START DATE        COMPANY  Total Income  \
# 0     Felix Kern   1            10  1997-10-23  Julie Chan AG          3850
# 1  Ishmail Ahmed   2            11  1997-11-05  Julie Chan AG          4253
#
#    Average Income
# 0          3675.0
# 1          4128.0

# %%
# get the highest salary earner(s)
df.sort_values(by=['SALARY'], ascending=False, inplace=False)
# Out:
#      EMP_ID       FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 41       41    Michael Power   Marketing    5000                 550
# 30       30       José Pedro    Engineer    5000                 250
# 131     131    Yoshi Latimer  Production    5000                 350
# 3         3        aria cruz  Production    5000                 350
# 97       97       José Pedro    Engineer    5000                 250
# ..      ...              ...         ...     ...                 ...
# 71       71      Becky David  Production    2000                 350
# 9         9   Chidinma Okoye          HR    2000                 200
# 76       76   Chidinma Okoye          HR    2000                 200
# 4         4      Becky David  Production    2000                 350
# 130     130  Yetunde Oladele          IT    2000                 200
#
#           MANAGERS   ID  INVENTORY ID  START DATE        COMPANY  \
# 41     Tina Turner   42            51  1998-02-02  Julie Chan AG
# ...

# %%
# get the lowest salary earner(s)
df.sort_values(by=['SALARY'],  inplace=False)
# Out:
#      EMP_ID         FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 63       63    Yetunde Oladele          IT    2000                 200
# 130     130    Yetunde Oladele          IT    2000                 200
# 71       71        Becky David  Production    2000                 350
# 76       76     Chidinma Okoye          HR    2000                 200
# 4         4        Becky David  Production    2000                 350
# ..      ...                ...         ...     ...                 ...
# 64       64      Yoshi Latimer  Production    5000                 350
# 108     108      Michael Power   Marketing    5000                 550
# 30       30         José Pedro    Engineer    5000                 250
# 97       97         José Pedro    Engineer    5000                 250
# 14       14  Elizabeth Lincoln    Engineer    5000                 250
#
#           MANAGERS   ID  INVENTORY ID  START DATE        COMPANY  \
# ...

# %%
# get the details of the worker with amployee id 100
df.loc[100]
# Out:
# EMP_ID                             100
# FULL NAMES            Laurence Lebihan
# DEPARTMENT                          HR
# SALARY                            4003
# DEPARTMENTAL BONUS                 200
# MANAGERS                     Gift Wyse
# ID                                 101
# INVENTORY ID                       110
# START DATE                  1997-11-07
# COMPANY                  Julie Chan AG
# Total Income                      4203
# Average Income                  4103.0
# Name: 100, dtype: object

# %%
# three employees with employee id 102,34,77 lost their ID card. please retrive their information so that we can send it to their office
df.loc[[102,34,77]]
# Out:
#      EMP_ID      FULL NAMES DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 102     102  Manuel Pereira         IT    3500                 200
# 34       34  Lino Rodriguez    Finance    4000                 150
# 77       77   Daniel Tonini         IT    4000                 200
#
#        MANAGERS   ID  INVENTORY ID  START DATE        COMPANY  Total Income  \
# 102  Brian Hart  103           112  1998-01-16  Julie Chan AG          3700
# 34    Gift Wyse   35            44  1997-02-21  Julie Chan AG          4150
# 77   Brian Hart   78            87  1997-06-30  Julie Chan AG          4200
#
#      Average Income
# 102          3600.0
# 34           4075.0
# 77           4100.0

# %%
# get the employees that are the highest earners based on salary and bonus
df.sort_values(by=['SALARY','DEPARTMENTAL BONUS'], ascending=True, inplace=False)
# Out:
#      EMP_ID       FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 9         9   Chidinma Okoye          HR    2000                 200
# 63       63  Yetunde Oladele          IT    2000                 200
# 76       76   Chidinma Okoye          HR    2000                 200
# 130     130  Yetunde Oladele          IT    2000                 200
# 4         4      Becky David  Production    2000                 350
# ..      ...              ...         ...     ...                 ...
# 64       64    Yoshi Latimer  Production    5000                 350
# 70       70        aria cruz  Production    5000                 350
# 131     131    Yoshi Latimer  Production    5000                 350
# 41       41    Michael Power   Marketing    5000                 550
# 108     108    Michael Power   Marketing    5000                 550
#
#           MANAGERS   ID  INVENTORY ID  START DATE        COMPANY  \
# 9    Nikola Market   10            19  1998-05-06  Julie Chan AG
# ...

# %%
# capitalise all column names
df.columns=df.columns.str.upper()

# %%
df.head(1)
# Out:
#    EMP_ID     FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS    MANAGERS  \
# 0       0  André Fonseca  Production    3500                 350  Felix Kern
#
#    ID  INVENTORY ID  START DATE        COMPANY  TOTAL INCOME  AVERAGE INCOME
# 0   1            10  1997-10-23  Julie Chan AG          3850          3675.0

# %%
# get the highest salary
df['SALARY'].max()
# Out:
# 5000

# %%
# get the Lowest salary
df['SALARY'].min()
# Out:
# 2000

# %%
# calculate the total income paid. Both salary and Bonus
sum(df['SALARY'] + df['DEPARTMENTAL BONUS'])
# Out:
# 490180

# %%
SALARY=sum(df['SALARY'])

# %%
BONUS=sum(df['DEPARTMENTAL BONUS'])

# %%
SALARY + BONUS
# Out:
# 490180

# %%
# get the bonus percentage
df['Profit']=df['TOTAL INCOME'] / df['SALARY']

# %%
df.head(2)
# Out:
#    EMP_ID     FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 0       0  André Fonseca  Production    3500                 350
# 1       1      Ann devon    Engineer    4003                 250
#
#         MANAGERS  ID  INVENTORY ID  START DATE        COMPANY  TOTAL INCOME  \
# 0     Felix Kern   1            10  1997-10-23  Julie Chan AG          3850
# 1  Ishmail Ahmed   2            11  1997-11-05  Julie Chan AG          4253
#
#    AVERAGE INCOME    Profit
# 0          3675.0  1.100000
# 1          4128.0  1.062453
