# %%
import pandas as pd
import numpy as np

# %%
# load data
df=pd.read_csv('Data_csv')

# %%
df.head(2)
# Out:
#    EMP_ID     FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 0       0  André Fonseca  Production    3500                 350
# 1       1      Ann devon    Engineer    4003                 250
#
#         MANAGERS  ID  INVENTORY ID  START DATE        COMPANY  Total Income  \
# 0     Felix Kern   1            10  1997-10-23  Julie Chan AG          3850
# 1  Ishmail Ahmed   2            11  1997-11-05  Julie Chan AG          4253
#
#    Average Income
# 0          3675.0
# 1          4128.0

# %%
# get the salary of the employee with employee id 300
df.loc[130,'SALARY']
# Out:
# 2000

# %%
# select all numerisc columns
df.select_dtypes(include='number')
# Out:
#      EMP_ID  SALARY  DEPARTMENTAL BONUS   ID  INVENTORY ID  Total Income  \
# 0         0    3500                 350    1            10          3850
# 1         1    4003                 250    2            11          4253
# 2         2    3000                 200    3            12          3200
# 3         3    5000                 350    4            13          5350
# 4         4    2000                 350    5            14          2350
# ..      ...     ...                 ...  ...           ...           ...
# 128     128    4000                 350  129           138          4350
# 129     129    4000                 350  130           139          4350
# 130     130    2000                 200  131           140          2200
# 131     131    5000                 350  132           141          5350
# 132     132    2200                 200  133           142          2400
#
#      Average Income
# 0            3675.0
# 1            4128.0
# 2            3100.0
# ...

# %%
# select all non numerisc columns
df.select_dtypes(exclude='number')
# Out:
#             FULL NAMES  DEPARTMENT       MANAGERS  START DATE        COMPANY
# 0        André Fonseca  Production     Felix Kern  1997-10-23  Julie Chan AG
# 1            Ann devon    Engineer  Ishmail Ahmed  1997-11-05  Julie Chan AG
# 2       Annette Roulet          IT     Brian Hart  1997-11-06  Julie Chan AG
# 3            aria cruz  Production     Felix Kern  1997-11-26  Julie Chan AG
# 4          Becky David  Production     Felix Kern  1998-01-12  Julie Chan AG
# ..                 ...         ...            ...         ...            ...
# 128  Victoria Ashworth  Production    Tina Turner  1996-10-16  Julie Chan AG
# 129          yang wang  Production  Nikola Market  1996-10-29  Julie Chan AG
# 130    Yetunde Oladele          IT     Felix Kern  1996-11-25  Julie Chan AG
# 131      Yoshi Latimer  Production  Nikola Market  1997-03-11  Julie Chan AG
# 132    Yoshi Tannamuri          IT  Ishmail Ahmed  1997-04-18  Julie Chan AG
#
# [133 rows x 5 columns]

# %%
# get the department with the highest numbers of workers
df.value_counts('DEPARTMENT').head(1)
# Out:
# DEPARTMENT
# IT    32
# dtype: int64

# %%
# get the department with the lowest numbers osf workers
df.value_counts('DEPARTMENT').tail(1)
# Out:
# DEPARTMENT
# Marketing    8
# dtype: int64

# %%
# who is the manager of the employee with id number 127
df.loc[127,'MANAGERS']
# Out:
# 'Brian Hart'

# %%
df.loc[127]
# Out:
# EMP_ID                          127
# FULL NAMES             Tonia Robert
# DEPARTMENT                    Sales
# SALARY                         3500
# DEPARTMENTAL BONUS              500
# MANAGERS                 Brian Hart
# ID                              128
# INVENTORY ID                    137
# START DATE               1998-03-24
# COMPANY               Julie Chan AG
# Total Income                   4000
# Average Income               3750.0
# MANAGER                         NaN
# Name: 127, dtype: object

# %%
# make emp_id an index
df.set_index('EMP_ID')
# Out:
#                FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# EMP_ID
# 0           André Fonseca  Production    3500                 350
# 1               Ann devon    Engineer    4003                 250
# 2          Annette Roulet          IT    3000                 200
# 3               aria cruz  Production    5000                 350
# 4             Becky David  Production    2000                 350
# ...                   ...         ...     ...                 ...
# 128     Victoria Ashworth  Production    4000                 350
# 129             yang wang  Production    4000                 350
# 130       Yetunde Oladele          IT    2000                 200
# 131         Yoshi Latimer  Production    5000                 350
# 132       Yoshi Tannamuri          IT    2200                 200
#
#              MANAGERS   ID  INVENTORY ID  START DATE        COMPANY  \
# EMP_ID
# 0          Felix Kern    1            10  1997-10-23  Julie Chan AG
# ...

# %%
# change 7 id manager from brian hart to  Sam
df.loc[7,'MANAGERS']='Joe Sam'

# %%
df.loc[7,'MANAGERS']
# Out:
# 'Joe Sam'

# %%
df.head(8)
# Out:
#    EMP_ID        FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 0       0     André Fonseca  Production    3500                 350
# 1       1         Ann devon    Engineer    4003                 250
# 2       2    Annette Roulet          IT    3000                 200
# 3       3         aria cruz  Production    5000                 350
# 4       4       Becky David  Production    2000                 350
# 5       5    Carine Schmitt  Production    4000                 350
# 6       6   Carlos González   Marketing    3000                 550
# 7       7  Carlos Hernández          IT    4003                 200
#
#         MANAGERS  ID  INVENTORY ID  START DATE        COMPANY  Total Income  \
# 0     Felix Kern   1            10  1997-10-23  Julie Chan AG          3850
# 1  Ishmail Ahmed   2            11  1997-11-05  Julie Chan AG          4253
# 2     Brian Hart   3            12  1997-11-06  Julie Chan AG          3200
# ...

# %%
# get the department of the employee with id 2 or second on the row
df.iloc[2,2]
# Out:
# 'IT'

# %%
#copy this data frame and name it IT
IT=df

# %%
IT.head(5)
# Out:
#    EMP_ID      FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 0       0   André Fonseca  Production    3500                 350
# 1       1       Ann devon    Engineer    4003                 250
# 2       2  Annette Roulet          IT    3000                 200
# 3       3       aria cruz  Production    5000                 350
# 4       4     Becky David  Production    2000                 350
#
#         MANAGERS  ID  INVENTORY ID  START DATE        COMPANY  Total Income  \
# 0     Felix Kern   1            10  1997-10-23  Julie Chan AG          3850
# 1  Ishmail Ahmed   2            11  1997-11-05  Julie Chan AG          4253
# 2     Brian Hart   3            12  1997-11-06  Julie Chan AG          3200
# 3     Felix Kern   4            13  1997-11-26  Julie Chan AG          5350
# 4     Felix Kern   5            14  1998-01-12  Julie Chan AG          2350
#
#    Average Income
# 0          3675.0
# 1          4128.0
# 2          3100.0
# 3          5175.0
# ...

# %%
# now get the workers in IT department
IT[
IT['DEPARTMENT']=='IT']
# Out:
#      EMP_ID        FULL NAMES DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 2         2    Annette Roulet         IT    3000                 200
# 7         7  Carlos Hernández         IT    4003                 200
# 10       10     Daniel Tonini         IT    4000                 200
# 16       16       Fran Wilson         IT    3000                 200
# 20       20     Helen Bennett         IT    3000                 200
# 21       21     howard synder         IT    2200                 200
# 24       24    Janek Podolski         IT    2300                 200
# 25       25     Janet Jackson         IT    4000                 100
# 29       29        Joke Silva         IT    4500                 200
# 32       32     Juliet Egbule         IT    3500                 200
# 35       35    Manuel Pereira         IT    3500                 200
# 48       48     Peter Franken         IT    3000                 200
# 51       51    Renate Messner         IT    3500                 200
# ...

# %%
# get the details of workers in HR 
HR = df

# %%
HR[HR['DEPARTMENT']=='HR']
# Out:
#      EMP_ID        FULL NAMES DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 9         9    Chidinma Okoye         HR    2000                 200
# 28       28        john steel         HR    3500                 200
# 31       31       Julie Oscar         HR    2200                 200
# 33       33  Laurence Lebihan         HR    4003                 200
# 37       37      Mario Pontes         HR    3500                 200
# 39       39       Marvin Gaye         HR    3500                 200
# 76       76    Chidinma Okoye         HR    2000                 200
# 95       95        john steel         HR    3500                 200
# 98       98       Julie Oscar         HR    2200                 200
# 100     100  Laurence Lebihan         HR    4003                 200
# 104     104      Mario Pontes         HR    3500                 200
# 106     106       Marvin Gaye         HR    3500                 200
#
#           MANAGERS   ID  INVENTORY ID  START DATE        COMPANY  \
# ...

# %%
HR is df
# Out:
# True

# %%
# who is the highest salary earner in HR department
HR[HR['DEPARTMENT']=='HR'].sort_values(by='SALARY', ascending=False)
# Out:
#      EMP_ID        FULL NAMES DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 33       33  Laurence Lebihan         HR    4003                 200
# 100     100  Laurence Lebihan         HR    4003                 200
# 28       28        john steel         HR    3500                 200
# 37       37      Mario Pontes         HR    3500                 200
# 39       39       Marvin Gaye         HR    3500                 200
# 95       95        john steel         HR    3500                 200
# 104     104      Mario Pontes         HR    3500                 200
# 106     106       Marvin Gaye         HR    3500                 200
# 31       31       Julie Oscar         HR    2200                 200
# 98       98       Julie Oscar         HR    2200                 200
# 9         9    Chidinma Okoye         HR    2000                 200
# 76       76    Chidinma Okoye         HR    2000                 200
#
#           MANAGERS   ID  INVENTORY ID  START DATE        COMPANY  \
# ...

# %%
# who is the lowest salary earner in IT department
HR[HR['DEPARTMENT']=='IT'].sort_values(by='SALARY')
# Out:
#      EMP_ID        FULL NAMES DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 130     130   Yetunde Oladele         IT    2000                 200
# 63       63   Yetunde Oladele         IT    2000                 200
# 65       65   Yoshi Tannamuri         IT    2200                 200
# 88       88     howard synder         IT    2200                 200
# 21       21     howard synder         IT    2200                 200
# 132     132   Yoshi Tannamuri         IT    2200                 200
# 24       24    Janek Podolski         IT    2300                 200
# 91       91    Janek Podolski         IT    2300                 200
# 115     115     Peter Franken         IT    3000                 200
# 87       87     Helen Bennett         IT    3000                 200
# 83       83       Fran Wilson         IT    3000                 200
# 20       20     Helen Bennett         IT    3000                 200
# 69       69    Annette Roulet         IT    3000                 200
# ...

# %%
# check for duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [EMP_ID, FULL NAMES, DEPARTMENT, SALARY, DEPARTMENTAL BONUS, MANAGERS, ID, INVENTORY ID, START DATE, COMPANY, Total Income, Average Income]
# Index: []

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 128    False
# 129    False
# 130    False
# 131    False
# 132    False
# Length: 133, dtype: bool

# %%
# check unique values
df.nunique()
# Out:
# EMP_ID                133
# FULL NAMES             67
# DEPARTMENT              7
# SALARY                 11
# DEPARTMENTAL BONUS      7
# MANAGERS                7
# ID                    133
# INVENTORY ID          133
# START DATE             83
# COMPANY                 1
# Total Income           33
# Average Income         34
# dtype: int64

# %%
#remove duplicate
df=df.drop_duplicates(ignore_index=True)

# %%
# remove column id
df.drop('ID',axis=1,  inplace=True)

# %%
df
# Out:
#      EMP_ID         FULL NAMES  DEPARTMENT  SALARY  DEPARTMENTAL BONUS  \
# 0         0      André Fonseca  Production    3500                 350
# 1         1          Ann devon    Engineer    4003                 250
# 2         2     Annette Roulet          IT    3000                 200
# 3         3          aria cruz  Production    5000                 350
# 4         4        Becky David  Production    2000                 350
# ..      ...                ...         ...     ...                 ...
# 128     128  Victoria Ashworth  Production    4000                 350
# 129     129          yang wang  Production    4000                 350
# 130     130    Yetunde Oladele          IT    2000                 200
# 131     131      Yoshi Latimer  Production    5000                 350
# 132     132    Yoshi Tannamuri          IT    2200                 200
#
#           MANAGERS  INVENTORY ID  START DATE        COMPANY  Total Income  \
# ...
