# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.show()
import seaborn as sns

# %%
# load first all date set and append
df1 = pd.read_excel('Superstore.xlsx', sheet_name='Central')
df2 = pd.read_excel('Superstore.xlsx', sheet_name='East')
df3 = pd.read_excel('Superstore+South.xlsx', sheet_name='South')
df4 = pd.read_excel('Superstore.xlsx', sheet_name='West')

# %%
# append all table into a single table
df = pd.concat([df1,df2,df3,df4])

# %%
# show the first 5 rows
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    7981  CA-2011-103800 2013-01-03 2013-01-07  Standard Class    DP-13000
# 1     740  CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 2     741  CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 3     742  CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 4    7661  CA-2011-105417 2013-01-07 2013-01-12  Standard Class    VS-21820
#
#       Customer Name      Segment        Country        City  ... Postal Code  \
# 0     Darren Powers     Consumer  United States     Houston  ...       77095
# 1     Phillina Ober  Home Office  United States  Naperville  ...       60540
# 2     Phillina Ober  Home Office  United States  Naperville  ...       60540
# 3     Phillina Ober  Home Office  United States  Naperville  ...       60540
# 4  Vivek Sundaresam     Consumer  United States  Huntsville  ...       77340
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-LA-10003223  Office Supplies       Labels
# 2  Central  OFF-ST-10002743  Office Supplies      Storage
# 3  Central  OFF-BI-10004094  Office Supplies      Binders
# 4  Central  FUR-FU-10004864        Furniture  Furnishings
#
#                                         Product Name    Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1                                          Avery 508   11.784         3
# 2                      SAFCO Boltless Steel Shelving  272.736         3
# 3         GBC Standard Plastic Binding Systems Combs    3.540         2
# 4  Howard Miller 14-1/2" Diameter Chrome Round Wa...   76.728         3
#
#    Discount   Profit
# 0       0.2   5.5512
# 1       0.2   4.2717
# 2       0.2 -64.7748
# 3       0.8  -5.4870
# 4       0.6 -53.7096
#
# [5 rows x 21 columns]

# %%
# retrieve the last 5 rows
df.tail(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3198    5457  CA-2014-130631 2016-12-29 2017-01-02  Standard Class
# 3199    5458  CA-2014-130631 2016-12-29 2017-01-02  Standard Class
# 3200    1297  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 3201    1298  CA-2014-115427 2016-12-30 2017-01-03  Standard Class
# 3202    5092  CA-2014-156720 2016-12-30 2017-01-03  Standard Class
#
#      Customer ID  Customer Name    Segment        Country       City  ...  \
# 3198    BS-11755  Bruce Stewart   Consumer  United States    Edmonds  ...
# 3199    BS-11755  Bruce Stewart   Consumer  United States    Edmonds  ...
# 3200    EB-13975     Erica Bern  Corporate  United States  Fairfield  ...
# 3201    EB-13975     Erica Bern  Corporate  United States  Fairfield  ...
# 3202    JM-15580  Jill Matthias   Consumer  United States   Loveland  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 3198       98026    West  OFF-FA-10000089  Office Supplies    Fasteners
# 3199       98026    West  FUR-FU-10004093        Furniture  Furnishings
# 3200       94533    West  OFF-BI-10002103  Office Supplies      Binders
# 3201       94533    West  OFF-BI-10004632  Office Supplies      Binders
# 3202       80538    West  OFF-FA-10003472  Office Supplies    Fasteners
#
#                                          Product Name   Sales  Quantity  \
# 3198                                 Acco Glide Clips  19.600         5
# 3199          Hand-Finished Solid Wood Document Frame  68.460         2
# 3200  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl  13.904         2
# 3201                               GBC Binding covers  20.720         2
# 3202                              Bagged Rubber Bands   3.024         3
#
#       Discount   Profit
# 3198       0.0   9.6040
# 3199       0.0  20.5380
# 3200       0.2   4.5188
# 3201       0.2   6.4750
# 3202       0.2  -0.6048
#
# [5 rows x 21 columns]

# %%
# check data types, change to right data type when necessary
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
# check numbers of coloumns and rows
df.shape
# Out:
# (9994, 21)

# %%
# check for null values
df.isna()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 3198   False     False       False      False      False        False
# 3199   False     False       False      False      False        False
# 3200   False     False       False      False      False        False
# 3201   False     False       False      False      False        False
# 3202   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# 0             False    False    False  False  ...        False   False
# 1             False    False    False  False  ...        False   False
# 2             False    False    False  False  ...        False   False
# 3             False    False    False  False  ...        False   False
# 4             False    False    False  False  ...        False   False
# ...             ...      ...      ...    ...  ...          ...     ...
# 3198          False    False    False  False  ...        False   False
# 3199          False    False    False  False  ...        False   False
# 3200          False    False    False  False  ...        False   False
# 3201          False    False    False  False  ...        False   False
# 3202          False    False    False  False  ...        False   False
#
#       Product ID  Category  Sub-Category  Product Name  Sales  Quantity  \
# 0          False     False         False         False  False     False
# 1          False     False         False         False  False     False
# 2          False     False         False         False  False     False
# 3          False     False         False         False  False     False
# 4          False     False         False         False  False     False
# ...          ...       ...           ...           ...    ...       ...
# 3198       False     False         False         False  False     False
# 3199       False     False         False         False  False     False
# 3200       False     False         False         False  False     False
# 3201       False     False         False         False  False     False
# 3202       False     False         False         False  False     False
#
#       Discount  Profit
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
# ...        ...     ...
# 3198     False   False
# 3199     False   False
# 3200     False   False
# 3201     False   False
# 3202     False   False
#
# [9994 rows x 21 columns]

# %%
#check for data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9994 entries, 0 to 3202
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.7+ MB

# %%
# get the statistic info
df.select_dtypes(include='float').describe()
# Out:
#               Sales     Discount       Profit
# count   9994.000000  9994.000000  9994.000000
# mean     229.858001     0.156203    28.656896
# std      623.245101     0.206452   234.260108
# min        0.444000     0.000000 -6599.978000
# 25%       17.280000     0.000000     1.728750
# 50%       54.490000     0.200000     8.666500
# 75%      209.940000     0.200000    29.364000
# max    22638.480000     0.800000  8399.976000

# %%
# create a new column by calculating the total sales
df["TOTAL SALES"] = df["SALES"] * df["QUANTITY"]
df.head()
# Out:
#    ROWID         ORDERID  ORDERDATE   SHIPDATE        SHIPMODE CUSTOMERID  \
# 0   7981  CA-2011-103800 2013-01-03 2013-01-07  Standard Class   DP-13000
# 1    740  CA-2011-112326 2013-01-04 2013-01-08  Standard Class   PO-19195
# 2    741  CA-2011-112326 2013-01-04 2013-01-08  Standard Class   PO-19195
# 3    742  CA-2011-112326 2013-01-04 2013-01-08  Standard Class   PO-19195
# 4   7661  CA-2011-105417 2013-01-07 2013-01-12  Standard Class   VS-21820
#
#        CUSTOMERNAME      SEGMENT        COUNTRY        CITY  ...   REGION  \
# 0     Darren Powers     Consumer  United States     Houston  ...  Central
# 1     Phillina Ober  Home Office  United States  Naperville  ...  Central
# 2     Phillina Ober  Home Office  United States  Naperville  ...  Central
# 3     Phillina Ober  Home Office  United States  Naperville  ...  Central
# 4  Vivek Sundaresam     Consumer  United States  Huntsville  ...  Central
#
#          PRODUCTID         CATEGORY  SUBCATEGORY  \
# 0  OFF-PA-10000174  Office Supplies        Paper
# 1  OFF-LA-10003223  Office Supplies       Labels
# 2  OFF-ST-10002743  Office Supplies      Storage
# 3  OFF-BI-10004094  Office Supplies      Binders
# 4  FUR-FU-10004864        Furniture  Furnishings
#
#                                          PRODUCTNAME    SALES QUANTITY  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448        2
# 1                                          Avery 508   11.784        3
# 2                      SAFCO Boltless Steel Shelving  272.736        3
# 3         GBC Standard Plastic Binding Systems Combs    3.540        2
# 4  Howard Miller 14-1/2" Diameter Chrome Round Wa...   76.728        3
#
#    DISCOUNT   PROFIT  TOTAL SALES
# 0       0.2   5.5512       32.896
# 1       0.2   4.2717       35.352
# 2       0.2 -64.7748      818.208
# 3       0.8  -5.4870        7.080
# 4       0.6 -53.7096      230.184
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (9994, 22)

# %%
# delete ROW ID column
del df['ROWID']

# %%
# add a new column and name it row id, then set it as index
df['ROLLID'] = np.arange(1,9995)
df = df.set_index('ROLLID')
df.head(1)
# Out:
#                ORDERID  ORDERDATE   SHIPDATE        SHIPMODE CUSTOMERID  \
# ROLLID
# 1       CA-2011-103800 2013-01-03 2013-01-07  Standard Class   DP-13000
#
#          CUSTOMERNAME   SEGMENT        COUNTRY     CITY  STATE  ...   REGION  \
# ROLLID                                                          ...
# 1       Darren Powers  Consumer  United States  Houston  Texas  ...  Central
#
#               PRODUCTID         CATEGORY SUBCATEGORY  \
# ROLLID
# 1       OFF-PA-10000174  Office Supplies       Paper
#
#                                               PRODUCTNAME   SALES  QUANTITY  \
# ROLLID
# 1       Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.448         2
#
#         DISCOUNT  PROFIT  TOTAL SALES
# ROLLID
# 1            0.2  5.5512       32.896
#
# [1 rows x 21 columns]

# %%
#create a new column by calculating profit %
df["PROFIT RATE"] = df["PROFIT"] / df["TOTAL SALES"]
df.head()
# Out:
#                ORDERID  ORDERDATE   SHIPDATE        SHIPMODE CUSTOMERID  \
# ROLLID
# 1       CA-2011-103800 2013-01-03 2013-01-07  Standard Class   DP-13000
# 2       CA-2011-112326 2013-01-04 2013-01-08  Standard Class   PO-19195
# 3       CA-2011-112326 2013-01-04 2013-01-08  Standard Class   PO-19195
# 4       CA-2011-112326 2013-01-04 2013-01-08  Standard Class   PO-19195
# 5       CA-2011-105417 2013-01-07 2013-01-12  Standard Class   VS-21820
#
#             CUSTOMERNAME      SEGMENT        COUNTRY        CITY     STATE  \
# ROLLID
# 1          Darren Powers     Consumer  United States     Houston     Texas
# 2          Phillina Ober  Home Office  United States  Naperville  Illinois
# 3          Phillina Ober  Home Office  United States  Naperville  Illinois
# 4          Phillina Ober  Home Office  United States  Naperville  Illinois
# 5       Vivek Sundaresam     Consumer  United States  Huntsville     Texas
#
#         ...        PRODUCTID         CATEGORY  SUBCATEGORY  \
# ROLLID  ...
# 1       ...  OFF-PA-10000174  Office Supplies        Paper
# 2       ...  OFF-LA-10003223  Office Supplies       Labels
# 3       ...  OFF-ST-10002743  Office Supplies      Storage
# 4       ...  OFF-BI-10004094  Office Supplies      Binders
# 5       ...  FUR-FU-10004864        Furniture  Furnishings
#
#                                               PRODUCTNAME    SALES QUANTITY  \
# ROLLID
# 1       Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448        2
# 2                                               Avery 508   11.784        3
# 3                           SAFCO Boltless Steel Shelving  272.736        3
# 4              GBC Standard Plastic Binding Systems Combs    3.540        2
# 5       Howard Miller 14-1/2" Diameter Chrome Round Wa...   76.728        3
#
#         DISCOUNT   PROFIT  TOTAL SALES  PROFIT RATE
# ROLLID
# 1            0.2   5.5512       32.896     0.168750
# 2            0.2   4.2717       35.352     0.120833
# 3            0.2 -64.7748      818.208    -0.079167
# 4            0.8  -5.4870        7.080    -0.775000
# 5            0.6 -53.7096      230.184    -0.233333
#
# [5 rows x 22 columns]

# %%
# check column names. change any if necessary
df.columns
# Out:
# Index(['ORDERID', 'ORDERDATE', 'SHIPDATE', 'SHIPMODE', 'CUSTOMERID',
#        'CUSTOMERNAME', 'SEGMENT', 'COUNTRY', 'CITY', 'STATE', 'POSTCODE',
#        'REGION', 'PRODUCTID', 'CATEGORY', 'SUBCATEGORY', 'PRODUCTNAME',
#        'SALES', 'QUANTITY', 'DISCOUNT', 'PROFIT', 'TOTAL SALES',
#        'PROFIT RATE'],
#       dtype='object')

# %%
df.columns = ['ORDER ID', 'ORDER DATE', 'SHIP DATE', 'SHIP MODE', 'CUSTOMER ID',
       'CUSTOMER NAME', 'SEGMENT', 'COUNTRY', 'CITY', 'STATE', 'POST CODE',
       'REGION', 'PRODUCT ID', 'CATEGORY', 'SUB CATEGORY', 'PRODUCT NAME',
       'SALES', 'QUANTITY', 'DISCOUNT', 'PROFIT', 'TOTAL SALES',
       'PROFIT RATE']

# %%
#capitalise all column names
df.columns = df.columns.str.capitalize()
df.head(1)
# Out:
#               Order id Order date  Ship date       Ship mode Customer id  \
# ROLLID
# 1       CA-2011-103800 2013-01-03 2013-01-07  Standard Class    DP-13000
#
#         Customer name   Segment        Country     City  State  ...  \
# ROLLID                                                          ...
# 1       Darren Powers  Consumer  United States  Houston  Texas  ...
#
#              Product id         Category Sub category  \
# ROLLID
# 1       OFF-PA-10000174  Office Supplies        Paper
#
#                                              Product name   Sales Quantity  \
# ROLLID
# 1       Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.448        2
#
#         Discount  Profit  Total sales  Profit rate
# ROLLID
# 1            0.2  5.5512       32.896      0.16875
#
# [1 rows x 22 columns]

# %%
# calculate the total sales that was generated
total_sales = df['Total sales'].sum()
round(total_sales,2)
# Out:
# 11488062.07

# %%
# calculate the average sales
avg_sales = df['Total sales'].mean() 
round(avg_sales,2)
# Out:
# 1149.5

# %%
# calculate the total profit made

total_profit = df["Profit"].sum()
round(total_profit ,2)
# Out:
# 286397.02

# %%
# calculate the total quantity sold

total_quantity = df['Quantity'].sum()
total_quantity
# Out:
# 37873

# %%
# calculate the total numbers of customers 
total_customers = df['Customer name'].nunique()
total_customers
# Out:
# 793

# %%
# calculate the total numbers of products sold
total_products = df['Product name'].nunique()
total_products
# Out:
# 1850

# %%
# create a year column and extract from the order date
df['Year'] = df['Order date'].dt.year
df['Year']
# Out:
# ROLLID
# 1       2013
# 2       2013
# 3       2013
# 4       2013
# 5       2013
#         ...
# 9990    2016
# 9991    2016
# 9992    2016
# 9993    2016
# 9994    2016
# Name: Year, Length: 9994, dtype: int64

# %%
# retrieve the uniques years 
df['Year'].unique()
# Out:
# array([2013, 2014, 2015, 2016])

# %%
# which year has the highest profit so far
high_sales =  df.groupby('Year')['Profit'].sum()
high_sales.sort_values(ascending=False).head(1)
# Out:
# Year
# 2016    93507.5131
# Name: Profit, dtype: float64

# %%
# check the year(s) we met profit target of 60000 and above
target = df.groupby('Year')['Profit'].agg(sum) 
target[target>60000]
# Out:
# Year
# 2014    61618.6037
# 2015    81726.9308
# 2016    93507.5131
# Name: Profit, dtype: float64

# %%
# what is highest sales made in a day
highest_sales = df['Total sales'].max()
highest_sales
# Out:
# 135830.88

# %%
# get the details of the customer that generated the higest sales in a day
df['Total sales'].argmax()
# Out:
# 5232

# %%
top_cus = df.iloc[5232,[5,20]]
top_cus
# Out:
# Customer name    Sean Miller
# Total sales        135830.88
# Name: 5233, dtype: object

# %%
# what is lowest sales made in a day
lowest_sales = df['Total sales'].min()
lowest_sales
# Out:
# 0.44399999999999995

# %%
df['Total sales'].argmin()
# Out:
# 1835

# %%
# get the details of the customer that generated the lowest sales in a day
df.iloc[1835, [5,20]]
# Out:
# Customer name    Zuschuss Carroll
# Total sales                 0.444
# Name: 1836, dtype: object

# %% [markdown]
# ### calculate the total profit and sales made in each region.

# %%
#calculate the total profit and sales made in each region.

pro_sales_total = df.groupby('Region')['Profit','Total sales'].agg(sum)

pro_sales_total
# Out:
# /var/folders/rd/4nz6kn356z1g4h36gjmmy05c0000gn/T/ipykernel_53218/1788741069.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pro_sales_total = df.groupby('Region')['Profit','Total sales'].agg(sum)
#               Profit   Total sales
# Region
# Central   39706.3625  2.475833e+06
# East      91522.7800  3.379326e+06
# South     46749.4303  2.037675e+06
# West     108418.4489  3.595228e+06

# %% [markdown]
# ### Create a visulization for total sales made in every region

# %%
# regional sales visualization
reg_sales = df.groupby('Region')['Total sales'].agg(sum)
label = df['Region'].unique()

fig1, ax1 = plt.subplots()
ax1.pie(reg_sales,  labels=label, autopct='%1.1f%%')
ax1.axis('equal') 
plt.show()

# %% [markdown]
# ### how many times orders were made from each region

# %%
order_count = df.value_counts('Region')
print(order_count)
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# dtype: int64

# %%
# visualise the total order sold from each region
sns.countplot(df['Region'])
# Out:
# /Users/julietchan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# ### show the top 10 customers by total profit

# %%
top_ten = df.groupby('Customer name')['Profit'].sum().sort_values(ascending=False).head(10) 
print(top_ten)

#top 10 visualization
top_ten.plot(kind='bar', figsize=(12,6), color='green', 
             title='Top 10 Customer by Total Profit', ylabel='Profit'
            )
# Out:
# Customer name
# Tamara Chand            8981.3239
# Raymond Buch            6976.0959
# Sanjit Chand            5757.4119
# Hunter Lopez            5622.4292
# Adrian Barton           5444.8055
# Tom Ashbrook            4703.7883
# Christopher Martinez    3899.8904
# Keith Dawkins           3038.6254
# Andy Reiter             2884.6208
# Daniel Raglin           2869.0760
# Name: Profit, dtype: float64
# <AxesSubplot:title={'center':'Top 10 Customer by Total Profit'}, xlabel='Customer name', ylabel='Profit'>

# %% [markdown]
# ### show the bottom 10 customers by profit

# %%
bottom_ten = df.groupby('Customer name')['Profit'].sum().sort_values().head(10) 
print(bottom_ten)
# Out:
# Customer name
# Cindy Stewart      -6626.3895
# Grant Thornton     -4108.6589
# Luke Foster        -3583.9770
# Sharelle Roach     -3333.9144
# Henry Goldwyn      -2797.9635
# Nathan Cano        -2204.8072
# Sean Braxton       -2082.7451
# Sean Miller        -1980.7393
# Christine Phan     -1850.3029
# Natalie Fritzler   -1695.9714
# Name: Profit, dtype: float64

# %%
#top 10 visualization
bottom_ten.plot(kind='barh', figsize=(12,6), color='red', 
             title='Bottom 10 Customer by Total Profit', ylabel='Profit'
            )
# Out:
# <AxesSubplot:title={'center':'Bottom 10 Customer by Total Profit'}, ylabel='Customer name'>

# %% [markdown]
# ### show the yearly trend by sales and profit

# %%
#yearly sales
yearly_sales = df.pivot_table(index='Year', values='Profit')
yearly_sales
# Out:
#          Profit
# Year
# 2013  24.858994
# 2014  29.314274
# 2015  31.677105
# 2016  28.173400

# %%
#yearly profit
yearly_Profit = df.pivot_table(index='Year', values='Profit')
yearly_Profit
# Out:
#          Profit
# Year
# 2013  24.858994
# 2014  29.314274
# 2015  31.677105
# 2016  28.173400

# %%
# yearly sales and profit trend visualization

fig,axes =  plt.subplots(nrows=2,ncols=1, figsize=(12,8))


axes[0].plot(yearly_sales, color='r',
                  lw=2, ls='--', marker = 'o',
                  markersize=20,  markerfacecolor='green',
                  markeredgecolor='yellow',markeredgewidth=3)

axes[0].set_title('Yearly Trend by Sales',fontsize=22)
axes[0].set_xlabel('Year',fontsize=20)
axes[0].set_ylabel('Sales',fontsize=20)


axes[1].plot(yearly_Profit,color='blue',
                  lw=5, alpha=0.5, marker = '*',
                  markersize=20,  markerfacecolor='red',
                  markeredgecolor='black',
                  markeredgewidth=3)
axes[1].set_title('Yearly Trend by Profut',fontsize=22)
axes[1].set_xlabel('Year',fontsize=16)
axes[1].set_ylabel('Profit',fontsize=16)

plt.tight_layout()

# %% [markdown]
# ### show the top 5 profitable states

# %%
state= df.groupby('State')['Profit'].agg(sum)
top_5 = state.sort_values(ascending=False).head(5)
print(top_5)

top_5.plot.bar(title='Tpp 5 Profitable States',ylabel='Profit' ,
              figsize=(10,5), colormap='Paired'
              )
# Out:
# State
# California    76381.3871
# New York      74038.5486
# Washington    33402.6517
# Michigan      24463.1876
# Virginia      18597.9504
# Name: Profit, dtype: float64
# <AxesSubplot:title={'center':'Tpp 5 Profitable States'}, xlabel='State', ylabel='Profit'>

# %% [markdown]
# ### show the bottom 5 profitable states

# %%
state= df.groupby('State')['Profit'].agg(sum)
bottom_5 = state.sort_values(ascending=True).head(5)
print(bottom_5)

bottom_5.plot.bar(color='orange', title='Bottom 5 States by Profit',
            ylabel='Profit')
# Out:
# State
# Texas            -25729.3563
# Ohio             -16971.3766
# Pennsylvania     -15559.9603
# Illinois         -12607.8870
# North Carolina    -7490.9122
# Name: Profit, dtype: float64
# <AxesSubplot:title={'center':'Bottom 5 States by Profit'}, xlabel='State', ylabel='Profit'>

# %% [markdown]
# ### get the list of the highly purchase products.

# %%
#top 5 products
high_products = df.value_counts('Product name').head() 
high_products
# Out:
# Product name
# Staple envelope            48
# Staples                    46
# Easy-staple paper          46
# Avery Non-Stick Binders    20
# Staples in misc. colors    19
# dtype: int64

# %% [markdown]
# ### show profit generated in each category

# %%
cat_pro = df.groupby('Category')['Profit'].sum()
print(cat_pro)

sns.barplot(df['Category'], df['Profit'])
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64
# /Users/julietchan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %% [markdown]
# ### Sales vs Profit

# %%
plt.figure(figsize=(12,5))
plt.scatter(df['Total sales'], df['Profit'])
           
           
plt.title('Total Sales vs Profit', fontsize=20,color='r')
plt.xlabel('Total Sales',fontsize=16,color='r')
plt.ylabel('Profit',fontsize=16, color='r')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ### regional sales by category

# %%
reg_cat_sales = df.pivot_table(index='Region', columns='Category',
                              values='Total sales',
                              aggfunc=sum)
print(reg_cat_sales )


reg_cat_sales.plot(kind='bar', ylabel='Total Sales', 
                   title='Regional Sales by Category')
# Out:
# Category     Furniture  Office Supplies   Technology
# Region
# Central   8.182364e+05       840684.441   816912.088
# East      1.102562e+06      1017023.425  1259740.789
# South     6.461502e+05       605808.745   785716.414
# West      1.292267e+06      1085068.707  1217892.234
# <AxesSubplot:title={'center':'Regional Sales by Category'}, xlabel='Region', ylabel='Total Sales'>

# %% [markdown]
# ### save regional sales by category chart as a pdf file

# %%
plt.savefig('reg_cat_sales.pdf')

# %% [markdown]
# ### regional Profit by category

# %%
regional_Cat = df.pivot_table(index='Category', 
                                 values='Profit',
                                 columns='Region',
                                 aggfunc=sum)
print(regional_Cat)



regional_Cat.plot.bar(figsize=(12,5), stacked=True,
                         title ='Regional Profit by Category',
                         ylabel='Total Profit', xlabel='Category'
                        )
# Out:
# Region              Central        East       South        West
# Category
# Furniture        -2871.0494   3046.1658   6771.2061  11504.9503
# Office Supplies   8879.9799  41014.5791  19986.3928  52609.8490
# Technology       33697.4320  47462.0351  19991.8314  44303.6496
# <AxesSubplot:title={'center':'Regional Profit by Category'}, xlabel='Category', ylabel='Total Profit'>

# %% [markdown]
# ### retrive the details of every customer order info from east region

# %%
east_customer =df[ df['Region'] == 'East']
east_customer
# Out:
#               Order id Order date  Ship date       Ship mode Customer id  \
# ROLLID
# 2324    CA-2011-141817 2013-01-05 2013-01-12  Standard Class    MB-18085
# 2325    CA-2011-130092 2013-01-11 2013-01-14     First Class    SV-20365
# 2326    CA-2011-118192 2013-01-13 2013-01-18  Standard Class    MM-17920
# 2327    CA-2011-118192 2013-01-13 2013-01-18  Standard Class    MM-17920
# 2328    CA-2011-149524 2013-01-14 2013-01-15     First Class    BS-11590
# ...                ...        ...        ...             ...         ...
# 5167    CA-2014-164826 2016-12-28 2017-01-04  Standard Class    JF-15415
# 5168    US-2014-102638 2016-12-29 2016-12-31     First Class    MC-17845
# 5169    CA-2014-143259 2016-12-30 2017-01-03  Standard Class    PO-18865
# 5170    CA-2014-143259 2016-12-30 2017-01-03  Standard Class    PO-18865
# 5171    CA-2014-143259 2016-12-30 2017-01-03  Standard Class    PO-18865
#
#             Customer name    Segment        Country           City  \
# ROLLID
# 2324           Mick Brown   Consumer  United States   Philadelphia
# 2325          Seth Vernon   Consumer  United States          Dover
# 2326        Michael Moore   Consumer  United States         Newark
# 2327        Michael Moore   Consumer  United States         Newark
# 2328        Brendan Sweed  Corporate  United States   Philadelphia
# ...                   ...        ...            ...            ...
# 5167    Jennifer Ferguson   Consumer  United States  New York City
# 5168         Michael Chen   Consumer  United States  New York City
# 5169    Patrick O'Donnell   Consumer  United States  New York City
# 5170    Patrick O'Donnell   Consumer  United States  New York City
# 5171    Patrick O'Donnell   Consumer  United States  New York City
#
#                State  ...         Category Sub category  \
# ROLLID                ...
# 2324    Pennsylvania  ...  Office Supplies          Art
# 2325        Delaware  ...        Furniture  Furnishings
# 2326            Ohio  ...  Office Supplies        Paper
# 2327            Ohio  ...  Office Supplies      Binders
# 2328    Pennsylvania  ...        Furniture    Bookcases
# ...              ...  ...              ...          ...
# 5167        New York  ...       Technology       Phones
# 5168        New York  ...  Office Supplies    Fasteners
# 5169        New York  ...        Furniture    Bookcases
# 5170        New York  ...       Technology       Phones
# 5171        New York  ...  Office Supplies      Binders
#
#                                              Product name    Sales Quantity  \
# ROLLID
# 2324    Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536        3
# 2325      DAX Value U-Channel Document Frames, Easel Back    9.940        2
# 2326                                           Xerox 1923   37.408        7
# 2327                          Avery Metallic Poly Binders    3.438        2
# 2328                Sauder Cornerstone Collection Library   61.960        4
# ...                                                   ...      ...      ...
# 5167    Cush Cases Heavy Duty Rugged Cover Case for Sa...   14.850        3
# 5168                                         Ideal Clamps    6.030        3
# 5169    Bush Westfield Collection Bookcases, Fully Ass...  323.136        4
# 5170                            Gear Head AU3700S Headset   90.930        7
# 5171                 Wilson Jones Legal Size Ring Binders   52.776        3
#
#        Discount   Profit  Total sales  Profit rate  Year
# ROLLID
# 2324        0.2   4.8840       58.608     0.083333  2013
# 2325        0.0   3.0814       19.880     0.155000  2013
# 2326        0.2  13.0928      261.856     0.050000  2013
# 2327        0.7  -2.5212        6.876    -0.366667  2013
# 2328        0.5 -53.2856      247.840    -0.215000  2013
# ...         ...      ...          ...          ...   ...
# 5167        0.0   4.0095       44.550     0.090000  2016
# 5168        0.0   2.9547       18.090     0.163333  2016
# 5169        0.2  12.1176     1292.544     0.009375  2016
# 5170        0.0   2.7279      636.510     0.004286  2016
# 5171        0.2  19.7910      158.328     0.125000  2016
#
# [2848 rows x 23 columns]

# %% [markdown]
# ### list out the customers that generated profit from 15 dollar and above

# %%
above_15 = df[df['Profit'] >= 15]
above_15
# Out:
#               Order id Order date  Ship date       Ship mode Customer id  \
# ROLLID
# 10      CA-2011-167927 2013-01-20 2013-01-26  Standard Class    XP-21865
# 12      CA-2011-167927 2013-01-20 2013-01-26  Standard Class    XP-21865
# 13      CA-2011-167927 2013-01-20 2013-01-26  Standard Class    XP-21865
# 19      CA-2011-167997 2013-01-26 2013-01-29     First Class    CA-11965
# 22      CA-2011-140795 2013-02-01 2013-02-03     First Class    BD-11500
# ...                ...        ...        ...             ...         ...
# 9981    CA-2014-163979 2016-12-28 2017-01-02    Second Class    KH-16690
# 9985    CA-2014-122798 2016-12-28 2017-01-01  Standard Class    SV-20935
# 9988    CA-2014-118885 2016-12-29 2017-01-02  Standard Class    JG-15160
# 9989    CA-2014-146626 2016-12-29 2017-01-05  Standard Class    BP-11185
# 9991    CA-2014-130631 2016-12-29 2017-01-02  Standard Class    BS-11755
#
#            Customer name    Segment        Country           City  \
# ROLLID
# 10          Xylona Preis   Consumer  United States       Westland
# 12          Xylona Preis   Consumer  United States       Westland
# 13          Xylona Preis   Consumer  United States       Westland
# 19           Carol Adams  Corporate  United States     Rapid City
# 22       Bradley Drucker   Consumer  United States      Green Bay
# ...                  ...        ...            ...            ...
# 9981    Kristen Hastings  Corporate  United States  San Francisco
# 9985     Susan Vittorini   Consumer  United States    Albuquerque
# 9988        James Galang   Consumer  United States    Los Angeles
# 9989        Ben Peterman  Corporate  United States        Anaheim
# 9991       Bruce Stewart   Consumer  United States        Edmonds
#
#                State  ...         Category Sub category  \
# ROLLID                ...
# 10          Michigan  ...        Furniture  Furnishings
# 12          Michigan  ...  Office Supplies   Appliances
# 13          Michigan  ...  Office Supplies      Storage
# 19      South Dakota  ...        Furniture    Bookcases
# 22         Wisconsin  ...       Technology  Accessories
# ...              ...  ...              ...          ...
# 9981      California  ...  Office Supplies      Storage
# 9985      New Mexico  ...  Office Supplies      Storage
# 9988      California  ...       Technology       Phones
# 9989      California  ...        Furniture  Furnishings
# 9991      Washington  ...        Furniture  Furnishings
#
#                                              Product name    Sales Quantity  \
# ROLLID
# 10      Eldon ClusterMat Chair Mat with Cordless Antis...  272.940        3
# 12      Holmes Replacement Filter for HEPA Air Cleaner...  247.716        4
# 13      Fellowes Bases and Tops For Staxonsteel/High-S...   66.580        2
# 19      Safco Value Mate Series Steel Bookcases, Baked...  141.960        2
# 22                           Enermax Aurora Lite Keyboard  468.900        6
# ...                                                   ...      ...      ...
# 9981                   Adjustable Depth Letter/Legal Cart  725.840        4
# 9985    Eldon Mobile Mega Data Cart  Mega Stackable  A...  118.250        5
# 9988                                     Adtran 1202752G1  302.376        3
# 9989                              Nu-Dell Executive Frame  101.120        8
# 9991              Hand-Finished Solid Wood Document Frame   68.460        2
#
#        Discount    Profit  Total sales  Profit rate  Year
# ROLLID
# 10          0.0   30.0234      818.820     0.036667  2013
# 12          0.1   93.5816      990.864     0.094444  2013
# 13          0.0   15.9792      133.160     0.120000  2013
# 19          0.0   39.7488      283.920     0.140000  2013
# 22          0.0  206.3160     2813.400     0.073333  2013
# ...         ...       ...          ...          ...   ...
# 9981        0.0  210.4936     2903.360     0.072500  2016
# 9985        0.0   34.2925      591.250     0.058000  2016
# 9988        0.2   22.6782      907.128     0.025000  2016
# 9989        0.0   37.4144      808.960     0.046250  2016
# 9991        0.0   20.5380      136.920     0.150000  2016
#
# [3812 rows x 23 columns]

# %% [markdown]
# ### rename the column Profit rate to profit %

# %%
# rename the column sub-category t0 sub category
df.rename(columns={'Profit rate':'Profit %'}, inplace=True)
df
# Out:
#               Order id Order date  Ship date       Ship mode Customer id  \
# ROLLID
# 1       CA-2011-103800 2013-01-03 2013-01-07  Standard Class    DP-13000
# 2       CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 3       CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 4       CA-2011-112326 2013-01-04 2013-01-08  Standard Class    PO-19195
# 5       CA-2011-105417 2013-01-07 2013-01-12  Standard Class    VS-21820
# ...                ...        ...        ...             ...         ...
# 9990    CA-2014-130631 2016-12-29 2017-01-02  Standard Class    BS-11755
# 9991    CA-2014-130631 2016-12-29 2017-01-02  Standard Class    BS-11755
# 9992    CA-2014-115427 2016-12-30 2017-01-03  Standard Class    EB-13975
# 9993    CA-2014-115427 2016-12-30 2017-01-03  Standard Class    EB-13975
# 9994    CA-2014-156720 2016-12-30 2017-01-03  Standard Class    JM-15580
#
#            Customer name      Segment        Country        City       State  \
# ROLLID
# 1          Darren Powers     Consumer  United States     Houston       Texas
# 2          Phillina Ober  Home Office  United States  Naperville    Illinois
# 3          Phillina Ober  Home Office  United States  Naperville    Illinois
# 4          Phillina Ober  Home Office  United States  Naperville    Illinois
# 5       Vivek Sundaresam     Consumer  United States  Huntsville       Texas
# ...                  ...          ...            ...         ...         ...
# 9990       Bruce Stewart     Consumer  United States     Edmonds  Washington
# 9991       Bruce Stewart     Consumer  United States     Edmonds  Washington
# 9992          Erica Bern    Corporate  United States   Fairfield  California
# 9993          Erica Bern    Corporate  United States   Fairfield  California
# 9994       Jill Matthias     Consumer  United States    Loveland    Colorado
#
#         ...         Category Sub category  \
# ROLLID  ...
# 1       ...  Office Supplies        Paper
# 2       ...  Office Supplies       Labels
# 3       ...  Office Supplies      Storage
# 4       ...  Office Supplies      Binders
# 5       ...        Furniture  Furnishings
# ...     ...              ...          ...
# 9990    ...  Office Supplies    Fasteners
# 9991    ...        Furniture  Furnishings
# 9992    ...  Office Supplies      Binders
# 9993    ...  Office Supplies      Binders
# 9994    ...  Office Supplies    Fasteners
#
#                                              Product name    Sales Quantity  \
# ROLLID
# 1       Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448        2
# 2                                               Avery 508   11.784        3
# 3                           SAFCO Boltless Steel Shelving  272.736        3
# 4              GBC Standard Plastic Binding Systems Combs    3.540        2
# 5       Howard Miller 14-1/2" Diameter Chrome Round Wa...   76.728        3
# ...                                                   ...      ...      ...
# 9990                                     Acco Glide Clips   19.600        5
# 9991              Hand-Finished Solid Wood Document Frame   68.460        2
# 9992      Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904        2
# 9993                                   GBC Binding covers   20.720        2
# 9994                                  Bagged Rubber Bands    3.024        3
#
#        Discount   Profit  Total sales  Profit %  Year
# ROLLID
# 1           0.2   5.5512       32.896  0.168750  2013
# 2           0.2   4.2717       35.352  0.120833  2013
# 3           0.2 -64.7748      818.208 -0.079167  2013
# 4           0.8  -5.4870        7.080 -0.775000  2013
# 5           0.6 -53.7096      230.184 -0.233333  2013
# ...         ...      ...          ...       ...   ...
# 9990        0.0   9.6040       98.000  0.098000  2016
# 9991        0.0  20.5380      136.920  0.150000  2016
# 9992        0.2   4.5188       27.808  0.162500  2016
# 9993        0.2   6.4750       41.440  0.156250  2016
# 9994        0.2  -0.6048        9.072 -0.066667  2016
#
# [9994 rows x 23 columns]
